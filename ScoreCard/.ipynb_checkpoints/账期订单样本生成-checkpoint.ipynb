# %% [markdown]
# ### 样本交易特征统计
# - 以账期订单为样本

# %%
#读取所有文件
import pandas as pd
import os
import numpy as np
import re
from funcs import *
import sys  
reload(sys)  
sys.setdefaultencoding('utf8')

# %%
#统计所有交易特征
def ac_feature(trade,t_now):
    print trade
    feature = []
    num = trade.shape[0] #订单数
    feature.append(num)
    feature.append(coo_months(trade[u'创建时间']))
    feature.append(recent_month(trade[u'创建时间'],t_now))
    feature.append(recent_last_month(trade[u'创建时间']))
    feature.append(time_gap(trade[u'创建时间']))
    t_num = trade[u'销售数量（吨）'].agg(['sum','max','min','std','mean'])
    t_money = trade[u'销售金额（元）'].agg(['sum','max','min','std','mean'])
    feature.extend(t_num)
    feature.extend(t_money)
    feature.append(trade_stab(trade))
    feature.append(trade[u'货物'].apply(lambda x:x.split(' ')[1]).value_counts().shape[0])
    feature.append(trade[u'货物'].apply(lambda x:x.split(' ')[0]).value_counts().shape[0])
        
    zhangqi = trade[trade[u'是否账期']==u'是']
    if zhangqi.shape[0]>0:
        feature.append(zhangqi.shape[0]*1.0/num)
        feature.append(zhangqi[u'销售数量（吨）'].mean())
        feature.append(zhangqi[u'销售金额（元）'].mean())
        feature.append(coo_months(zhangqi[u'创建时间']))
        feature.append(recent_month(zhangqi[u'创建时间'],t_now))
    else:
        feature.append(0)
        feature.append(0)
        feature.append(0)
        feature.append(0)
        feature.append(0)
    return feature

# %%
#统计每个客户账期订单数据
indexs = ['订单总数','合作时间（月）','最近交易（X月之前）','最近连续交易月数','订单时间间隔均值（天）','交易总量','交易量最大值',
          '交易量最小值','交易量方差','交易量均值','交易额总量','交易额最大值','交易额最小值','交易额方差',
          '交易额均值','交易稳定性（近三个月交易量变化均值）','供应商数量','采购产品种类数量',
          '账期订单占比','账期订单交易量均值','账期订单交易额均值','账期合作时间（月）','最近一笔账期订单（X月之前）']

def df_sub(record,trade):
    df = pd.DataFrame(index=indexs)    
    tmps = zip(record[u'应收单号'],record[u'起算日期'])
    for t in tmps:
        trade_sub = trade[trade[u'创建时间']<t[1]]
        if trade_sub.shape[0]>0:
            fs = ac_feature(trade_sub,t[1])
        else:
            fs = [0]*len(indexs)
        df[t[0]]=fs
    return df

# %%
#所有账期订单数据统计
zq_files = os.listdir('./data/loan_list/')
#所有订单数据
files = VisitDir('./data/client_data/')
files =[f for f in files if '交易记录' in f]

samples = pd.DataFrame()
for f in zq_files:
    record = pd.read_excel(os.path.join('./data/loan_list/',f))
    record = record.iloc[1:,:]  #账期数据
    for f1 in files:
        if f1.split('/')[-2]==f.split('.')[0]:
            trade = pd.read_excel(f1)   #交易数据
            df = df_sub(record,trade)          
            if samples.shape[0]==0:
                samples=df
            else:
                samples = samples.merge(df,left_index=True,right_index=True,how='left')
            continue
samples =samples.T
samples.to_csv('./data/zq_feature_trade.csv')

# %%
#归一化
t_cols =  ['订单总数','合作时间（月）','最近交易（X月之前）','最近连续交易月数','订单时间间隔均值（天）','交易总量','交易量最大值',
          '交易量最小值','交易量方差','交易量均值','交易额总量','交易额最大值','交易额最小值','交易额方差',
          '交易额均值','供应商数量','采购产品种类数量','账期订单交易量均值','账期订单交易额均值',
           '账期合作时间（月）','最近一笔账期订单（X月之前）']
for col in t_cols:
    samples[col]=normalize(samples[col])    
samples.to_csv('./data/zq_feature_trade_nor.csv')

# %%
samples.shape
# Out:
# (1430, 23)

# %% [markdown]
# ### 逾期样本订单

# %%
#所有逾期记录
files = os.listdir('./data/loan_list/')
loan_all = pd.DataFrame()
for f in files:
    record = pd.read_excel(os.path.join('./data/loan_list/',f))
    loan_all = loan_all.append(record.iloc[1:,:],ignore_index=True)
loan_all['zq_day'] = loan_all[u'账期'].apply(lambda x:re.findall('\d+',x)[0])
loan_all['yq_day'] = loan_all[u'逾期'].apply(lambda x:re.findall('^(-\d+|\d+)',x)[0])
loan_all['zq_day'] = loan_all['zq_day'].astype(int)
loan_all['yq_day'] = loan_all['yq_day'].apply(lambda x:int(x))
loan_all.to_csv('./data/loan_all.csv',index=None)
loan_all=loan_all.drop_duplicates()
loan_all.shape
# Out:
# (1430, 15)

# %%
loan_all[u'逾期占比']=0
loan_all[u'提前还款占比']=0
loan_all.shape
# Out:
# (1430, 17)

# %%
#统计
yq_ratio =[]
tq_ratio =[]
loan_all[u'起算日期'] =pd.to_datetime(loan_all[u'起算日期'])
for i in xrange(loan_all.shape[0]):
    name = loan_all.iat[i,1]
    time = loan_all.iat[i,10]
    loan_sub = loan_all[(loan_all[u'客户'] == name) & (loan_all[u'起算日期']<time)]
    if loan_sub.shape[0]>0:
        yq_ratio.append(loan_sub[loan_sub['yq_day']>0].shape[0]*1.0 / loan_sub.shape[0])
        tq_ratio.append( loan_sub[loan_sub['yq_day']<0].shape[0]*1.0 / loan_sub.shape[0])
    else:
        yq_ratio.append(0)
        tq_ratio.append(0)
        
loan_all[u'逾期占比']=yq_ratio
loan_all[u'提前还款占比']=tq_ratio
loan_all.head()
# Out:
#    业务类型                客户      已收金额   应收  应收余额              应收单号      应收总额  \
# 0  账期业务  佛山市南海区松岗明珠塑料有限公司  184520.0  NaN   0.0  YS20170228152309  184520.0
# 1  账期业务  佛山市南海区松岗明珠塑料有限公司  171990.0  NaN   0.0  YS20170103150373  171990.0
# 2  账期业务  佛山市南海区松岗明珠塑料有限公司  198450.0  NaN   0.0  YS20161117147341  198450.0
# 3  账期业务  佛山市南海区松岗明珠塑料有限公司  198450.0  NaN   0.0  YS20161115147142  198450.0
# 4  账期业务  佛山市南海区松岗明珠塑料有限公司  186940.0  NaN   0.0  YS20161025145675  186940.0
#
#         应收日期 收款状态   账期       起算日期   逾期                 销售合同号  zq_day  yq_day  \
# 0 2017-03-30  已收款  30天 2017-02-28  11天  ZSL20170227LL-C003WJ      30      11
# 1 2017-01-13  已收款  10天 2017-01-03   0天  ZSL20161228LL-C041WJ      10       0
# 2 2016-12-02  已收款  15天 2016-11-17  -2天  ZSL20161025LL-C009WJ      15      -2
# 3 2016-11-29  已收款  15天 2016-11-14   0天  ZSL20161025LL-C009WJ      15       0
# 4 2016-11-09  已收款  15天 2016-10-25   0天  ZSL20161011LL-C038WJ      15       0
#
#        逾期占比    提前还款占比
# 0  0.157895  0.263158
# 1  0.166667  0.277778
# 2  0.176471  0.235294
# 3  0.187500  0.250000
# 4  0.200000  0.266667

# %%
loan_all.to_csv('./data/loan_all.csv')

# %% [markdown]
# ### 合并样本特征

# %%
#账期订单特征
samples = pd.read_csv('./data/zq_feature_trade.csv',index_col=0)
samples.index = [x.encode('utf-8') for x in samples.index]
loan_all = pd.read_csv('./data/loan_all.csv')
tmp_loan = loan_all[['应收单号','逾期占比','提前还款占比','yq_day','zq_day','客户','收款状态']]
samples_all = samples.merge(tmp_loan,left_index=True,right_on='应收单号',how='left')
samples_all = samples_all.set_index('应收单号')
samples_all.shape
# Out:
# (1430, 29)

# %%
#客户公司基础特征
feature_card = pd.read_csv('./data/features_card.csv',index_col=0)
samples_all = samples_all.merge(feature_card,left_on='客户',right_index=True,how='left')
samples_all =samples_all.drop(['客户'],axis=1)
samples_all.head()
# Out:
#                   订单总数  合作时间（月）  最近交易（X月之前）  最近连续交易月数  订单时间间隔均值（天）    交易总量  \
# 应收单号
# YS20170228152309  19.0     13.0         0.0       3.0    20.555556  584.75
# YS20170103150373  17.0     11.0         1.0       1.0    19.312500  529.75
# YS20161117147341  16.0      9.0         1.0       9.0    16.333333  502.75
# YS20161115147142  16.0      9.0         1.0       9.0    16.333333  502.75
# YS20161025145675  15.0      9.0         0.0       9.0    16.642857  448.75
#
#                   交易量最大值  交易量最小值      交易量方差      交易量均值  ...    流动比率    净资产  \
# 应收单号                                                    ...
# YS20170228152309    54.0    20.0  10.354110  30.776316  ...   132.0  226.0
# YS20170103150373    54.0    20.0  10.912271  31.161765  ...   132.0  226.0
# YS20161117147341    54.0    20.0  11.215584  31.421875  ...   132.0  226.0
# YS20161115147142    54.0    20.0  11.215584  31.421875  ...   132.0  226.0
# YS20161025145675    50.0    20.0   9.794617  29.916667  ...   132.0  226.0
#
#                   货币资金  存货周转天数  应收账款周转天数  主营业务利润率  净资产增长率  销售增长率  当地经济环境  撮合单数
# 应收单号
# YS20170228152309  64.0    13.0      43.0      8.0    -7.0    1.0     8.3   0.0
# YS20170103150373  64.0    13.0      43.0      8.0    -7.0    1.0     8.3   0.0
# YS20161117147341  64.0    13.0      43.0      8.0    -7.0    1.0     8.3   0.0
# YS20161115147142  64.0    13.0      43.0      8.0    -7.0    1.0     8.3   0.0
# YS20161025145675  64.0    13.0      43.0      8.0    -7.0    1.0     8.3   0.0
#
# [5 rows x 57 columns]

# %%
samples_all.std().sort_values(ascending=False)
# Out:
# 交易额总量                 5.832114e+06
# 交易额最大值                5.290320e+05
# 账期订单交易额均值             2.108113e+05
# 交易额均值                 1.748172e+05
# 交易额方差                 1.617812e+05
# 交易额最小值                8.306186e+04
# 厂房面积                  4.166366e+04
# 实收资本                  1.116639e+03
# 交易总量                  9.453252e+02
# 净资产                   9.179821e+02
# 货币资金                  3.580792e+02
# 净资产增长率                2.818335e+02
# 流动比率                  2.078480e+02
# 员工人数                  1.846981e+02
# 存货周转天数                9.692956e+01
# 交易量最大值                9.505022e+01
# 销售增长率                 8.271477e+01
# 应收账款周转天数              4.976174e+01
# 账期订单交易量均值             3.561088e+01
# 交易量均值                 3.062841e+01
# 交易量方差                 2.727478e+01
# 订单时间间隔均值（天）           2.318480e+01
# 撮合单数                  2.205690e+01
# 资产负债率                 1.949537e+01
# 交易稳定性（近三个月交易量变化均值）    1.571226e+01
# 订单总数                  1.232857e+01
# 交易量最小值                1.230656e+01
# yq_day                9.521849e+00
# zq_day                9.485886e+00
# 主营业务利润率               5.601759e+00
# 注册时间                  4.675464e+00
# 合作时间（月）               4.423572e+00
# 账期合作时间（月）             3.847340e+00
# 最近连续交易月数              3.482976e+00
# 供应商数量                 2.713879e+00
# 当地经济环境                1.263873e+00
# 下游客户情况                9.988349e-01
# 涉诉信息                  6.682219e-01
# 采购产品种类数量              5.723873e-01
# 征信正常                  5.001471e-01
# 注册地址                  4.943362e-01
# 商标专利                  4.856097e-01
# 场地自有                  4.762292e-01
# 场地租赁                  4.762292e-01
# 最近交易（X月之前）            4.456241e-01
# 最近一笔账期订单（X月之前）        4.366148e-01
# 有无贷款                  4.020780e-01
# 征信欠息                  3.603813e-01
# 注册资本变更                3.452835e-01
# 提前还款占比                2.906266e-01
# 分支机构                  2.875878e-01
# 逾期占比                  2.695953e-01
# 征信关注                  2.550275e-01
# 账期订单占比                2.324297e-01
# 法人变更                  2.108200e-01
# 征信不良                  1.666005e-01
# dtype: float64

# %% [markdown]
# ### 按账期分产品
# - 账期<=7天，逾期大于5天为坏客户
# - 账期8-15天，逾期大于4天为坏客户
# - 账期>15天，逾期大于7天为坏客户

# %%
samples_all = samples_all[samples_all['收款状态']=='已收款']
zq_7 = samples_all[samples_all.zq_day<=7].drop(['zq_day','收款状态'],axis=1)
zq_15 = samples_all[(samples_all.zq_day>7) & (samples_all.zq_day<=15)].drop(['zq_day','收款状态'],axis=1)
zq_30 = samples_all[samples_all.zq_day>15].drop(['zq_day','收款状态'],axis=1)

# %%
zq_7['label'] = zq_7['yq_day'].apply(lambda x:1 if x>4 else 0)
zq_7 =zq_7.drop(['yq_day'],axis=1)
zq_15['label'] = zq_15['yq_day'].apply(lambda x:1 if x>3 else 0)
zq_15 =zq_15.drop(['yq_day'],axis=1)
zq_30['label'] = zq_30['yq_day'].apply(lambda x:1 if x>6 else 0)
zq_30 =zq_30.drop(['yq_day'],axis=1)

# %%
zq_7.to_csv('./data/samples_7.csv')
zq_15.to_csv('./data/samples_15.csv')
zq_30.to_csv('./data/samples_30.csv')

# %%
zq_7.std().sort_values(ascending=False)
# Out:
# 交易额总量                 6.225961e+06
# 交易额最大值                4.971326e+05
# 账期订单交易额均值             2.588724e+05
# 交易额均值                 1.984433e+05
# 交易额方差                 1.626833e+05
# 交易额最小值                7.652564e+04
# 厂房面积                  3.089440e+04
# 净资产                   1.081957e+03
# 交易总量                  1.000533e+03
# 实收资本                  9.335162e+02
# 流动比率                  2.879265e+02
# 货币资金                  2.612612e+02
# 净资产增长率                1.424062e+02
# 员工人数                  1.300615e+02
# 存货周转天数                1.016966e+02
# 交易量最大值                8.755084e+01
# 销售增长率                 5.948694e+01
# 应收账款周转天数              5.627565e+01
# 账期订单交易量均值             4.136927e+01
# 交易量均值                 3.333443e+01
# 订单时间间隔均值（天）           3.078044e+01
# 撮合单数                  3.062134e+01
# 交易量方差                 2.663955e+01
# 资产负债率                 2.045059e+01
# 交易稳定性（近三个月交易量变化均值）    1.998353e+01
# 订单总数                  1.417675e+01
# 交易量最小值                1.318843e+01
# 注册时间                  4.632357e+00
# 合作时间（月）               4.356938e+00
# 最近连续交易月数              3.849070e+00
# 主营业务利润率               3.773813e+00
# 账期合作时间（月）             3.285319e+00
# 供应商数量                 2.893889e+00
# 当地经济环境                1.495241e+00
# 下游客户情况                9.362558e-01
# 涉诉信息                  5.309730e-01
# 最近交易（X月之前）            5.012962e-01
# 最近一笔账期订单（X月之前）        4.882679e-01
# 征信正常                  4.849679e-01
# 商标专利                  4.829968e-01
# 注册地址                  4.728106e-01
# 场地租赁                  4.459749e-01
# 场地自有                  4.459749e-01
# 有无贷款                  4.287238e-01
# 征信欠息                  4.045202e-01
# 采购产品种类数量              3.838094e-01
# label                 3.361765e-01
# 注册资本变更                3.163563e-01
# 征信关注                  3.030101e-01
# 提前还款占比                3.016020e-01
# 账期订单占比                2.638878e-01
# 逾期占比                  2.586018e-01
# 分支机构                  2.262943e-01
# 法人变更                  2.075588e-01
# 征信不良                  3.874921e-02
# dtype: float64

# %%
zq_7[['提前还款占比','订单总数']]
# Out:
#                     提前还款占比  订单总数
# 应收单号
# YS2016080317738   0.222222  10.0
# YS2016071915487   0.250000   9.0
# YS2016070113517   0.285714   8.0
# YS2016050505611   0.400000   6.0
# YS20160913107905  0.333333  11.0
# YS20160911107730  0.363636  11.0
# YS2016072516482   0.222222  10.0
# YS2016072516481   0.222222  10.0
# YS2016070714094   0.250000   9.0
# YS2016062913080   0.142857   8.0
# YS2016062412633   0.000000   8.0
# YS2016062312293   0.000000   8.0
# YS2016061310460   0.000000   6.0
# YS2016052007711   0.000000   5.0
# YS2016051106276   0.000000   5.0
# YS20170314153009  0.333333  11.0
# YS20170228152326  0.200000  10.0
# YS20170112150913  0.000000   9.0
# YS20170104150388  0.000000   8.0
# YS20161221149603  0.000000   7.0
# YS20161205148426  0.000000   6.0
# YS20161205148425  0.000000   6.0
# YS20170109150628  0.250000  10.0
# YS20161109146812  0.333333   6.0
# YS20161103146353  0.000000   5.0
# YS20161102146292  0.000000   5.0
# YS20161020110526  0.000000   2.0
# YS20170510155341  0.833333  12.0
# YS20170503155084  0.800000  11.0
# YS20170407154030  0.750000  10.0
# ...                    ...   ...
# YS20161008109412  0.551724  52.0
# YS20160923108748  0.535714  51.0
# YS20160905107298  0.555556  48.0
# YS20160824106576  0.538462  48.0
# YS20160812171110  0.560000  48.0
# YS2016072917121   0.583333  46.0
# YS2016071815393   0.608696  46.0
# YS2016070814239   0.650000  42.0
# YS2016070814238   0.722222  41.0
# YS2016070413660   0.636364  44.0
# YS2016062913095   0.666667  43.0
# YS2016061410578   0.684211  42.0
# YS2016060209464   0.812500  41.0
# YS2016060109379   0.764706  41.0
# YS2016051807334   0.866667  41.0
# YS2016051606780   0.857143  40.0
# YS2016051006122   0.846154  39.0
# YS2016042905377   0.833333  38.0
# YS2016042705087   0.818182  38.0
# YS2016041803663   0.900000  37.0
# YS2016041403276   1.000000  37.0
# YS2016041102704   1.000000  36.0
# YS2016040702548   1.000000  35.0
# YS2016040502427   1.000000  35.0
# YS2016040502426   1.000000  35.0
# YS2016040502418   1.000000  35.0
# YS2016032301514   1.000000  32.0
# YS2016032201382   1.000000  32.0
# YS2016031400348   1.000000  31.0
# YS2016030700026   0.000000  29.0
#
# [671 rows x 2 columns]

# %%
#归一化
t_cols =['订单总数','合作时间（月）','最近交易（X月之前）','最近连续交易月数','订单时间间隔均值（天）','交易总量','交易量最大值',
         '交易量最小值','交易量方差','交易量均值','交易额总量','交易额最大值','交易额最小值','交易额方差','交易额均值','供应商数量',
         '采购产品种类数量','账期订单交易量均值','账期订单交易额均值','账期合作时间（月）','最近一笔账期订单（X月之前）','注册时间',
         '实收资本','员工人数','厂房面积','资产负债率','流动比率','净资产','货币资金','存货周转天数','应收账款周转天数','主营业务利润率',
         '净资产增长率','销售增长率','当地经济环境','撮合单数',]
for col in t_cols:
    zq_7[col] =normalize(zq_7[col])
    zq_15[col] =normalize(zq_15[col])
    zq_30[col] =normalize(zq_30[col])
zq_7.to_csv('./data/samples_7_nor.csv')
zq_15.to_csv('./data/samples_15_nor.csv')
zq_30.to_csv('./data/samples_30_nor.csv')

# %% [markdown]
# ### 计算IV值,特征相关性

# %%
ivs_7 = pd.DataFrame.from_dict([calc_iv(zq_7,box_num=3)]).T
ivs_7.sort_values(by=0,ascending=False).to_csv('./data/features_ivs_zq_7.csv')
ivs_7.sort_values(by=0,ascending=False)
# Out:
#                            0
# 提前还款占比              0.726691
# 下游客户情况              0.708709
# 征信关注                0.644166
# 员工人数                0.618418
# 注册时间                0.554756
# 逾期占比                0.545867
# 交易量方差               0.526118
# 交易量均值               0.520555
# 实收资本                0.510972
# 交易额均值               0.508468
# 交易额方差               0.475726
# 应收账款周转天数            0.465918
# 账期订单交易额均值           0.449625
# 厂房面积                0.443826
# 交易额最大值              0.429310
# 账期订单交易量均值           0.411186
# 交易量最大值              0.407179
# 资产负债率               0.394667
# 流动比率                0.379733
# 商标专利                0.356308
# 主营业务利润率             0.334207
# 交易总量                0.323404
# 供应商数量               0.319223
# 销售增长率               0.298994
# 交易额总量               0.296024
# 征信正常                0.292603
# 净资产                 0.286513
# 有无贷款                0.270158
# 存货周转天数              0.267820
# 订单时间间隔均值（天）         0.233720
# 净资产增长率              0.169366
# 货币资金                0.159384
# 注册地址                0.141987
# 场地自有                0.141469
# 场地租赁                0.141469
# 最近连续交易月数            0.140113
# 征信欠息                0.132276
# 当地经济环境              0.125754
# 涉诉信息                0.117862
# 合作时间（月）             0.101540
# 订单总数                0.085109
# 交易稳定性（近三个月交易量变化均值）  0.081800
# 撮合单数                0.069368
# 采购产品种类数量            0.064718
# 账期订单占比              0.063864
# 账期合作时间（月）           0.063795
# 最近交易（X月之前）          0.037644
# 最近一笔账期订单（X月之前）      0.033217
# 交易额最小值              0.028708
# 注册资本变更              0.026849
# 交易量最小值              0.024256
# 法人变更                0.018384
# 征信不良                0.013351
# 分支机构                0.001706

# %%
ivs_15 = pd.DataFrame.from_dict([calc_iv(zq_15,box_num=3)]).T
ivs_15.sort_values(by=0,ascending=False).to_csv('./data/features_ivs_zq_15.csv')
ivs_15.sort_values(by=0,ascending=False)
# Out:
#                            0
# 注册时间                0.604317
# 实收资本                0.576618
# 应收账款周转天数            0.566900
# 资产负债率               0.550702
# 提前还款占比              0.526196
# 主营业务利润率             0.457387
# 逾期占比                0.339988
# 账期订单占比              0.334333
# 存货周转天数              0.313965
# 流动比率                0.310079
# 销售增长率               0.250981
# 账期订单交易量均值           0.248271
# 交易稳定性（近三个月交易量变化均值）  0.237489
# 当地经济环境              0.220968
# 供应商数量               0.207408
# 交易额最大值              0.196906
# 交易额最小值              0.191453
# 交易量最小值              0.186653
# 场地租赁                0.167354
# 场地自有                0.167354
# 交易量均值               0.158372
# 交易量最大值              0.154496
# 净资产                 0.124642
# 厂房面积                0.123052
# 交易量方差               0.088609
# 采购产品种类数量            0.086295
# 订单时间间隔均值（天）         0.077537
# 员工人数                0.065205
# 净资产增长率              0.065032
# 涉诉信息                0.064066
# 货币资金                0.060914
# 有无贷款                0.060435
# 征信关注                0.052558
# 法人变更                0.050547
# 交易额总量               0.048500
# 订单总数                0.048057
# 分支机构                0.048037
# 账期订单交易额均值           0.037723
# 交易总量                0.037034
# 交易额方差               0.029331
# 撮合单数                0.021538
# 征信欠息                0.017898
# 商标专利                0.015355
# 合作时间（月）             0.014661
# 交易额均值               0.012855
# 账期合作时间（月）           0.010499
# 征信正常                0.009319
# 最近连续交易月数            0.009090
# 最近交易（X月之前）          0.009037
# 最近一笔账期订单（X月之前）      0.005930
# 下游客户情况              0.005911
# 注册资本变更              0.004184
# 注册地址                0.003534
# 征信不良                0.002019

# %%
ivs_30 = pd.DataFrame.from_dict([calc_iv(zq_30,box_num=2)]).T
ivs_30.sort_values(by=0,ascending=False).to_csv('./data/features_ivs_zq_30.csv')
ivs_30.sort_values(by=0,ascending=False)
# Out:
#                            0
# 下游客户情况              0.604152
# 主营业务利润率             0.598010
# 货币资金                0.583808
# 交易额最小值              0.516954
# 实收资本                0.497081
# 注册资本变更              0.426077
# 应收账款周转天数            0.422430
# 提前还款占比              0.408068
# 交易量最小值              0.364195
# 销售增长率               0.347467
# 流动比率                0.331084
# 涉诉信息                0.328386
# 逾期占比                0.307330
# 账期订单占比              0.290457
# 净资产                 0.267868
# 采购产品种类数量            0.267030
# 存货周转天数              0.259415
# 注册地址                0.253295
# 厂房面积                0.239564
# 注册时间                0.231668
# 员工人数                0.227409
# 净资产增长率              0.223585
# 资产负债率               0.212217
# 征信正常                0.212080
# 当地经济环境              0.192102
# 撮合单数                0.174948
# 征信不良                0.131683
# 交易量均值               0.130162
# 分支机构                0.093678
# 交易总量                0.092202
# 账期订单交易额均值           0.082449
# 交易额方差               0.081411
# 交易量最大值              0.069662
# 交易稳定性（近三个月交易量变化均值）  0.067377
# 账期订单交易量均值           0.061554
# 商标专利                0.061024
# 账期合作时间（月）           0.058776
# 合作时间（月）             0.050186
# 场地自有                0.049983
# 场地租赁                0.049983
# 有无贷款                0.048008
# 最近交易（X月之前）          0.044178
# 最近一笔账期订单（X月之前）      0.044178
# 供应商数量               0.044066
# 法人变更                0.033389
# 交易量方差               0.027342
# 交易额最大值              0.019390
# 征信关注                0.018977
# 征信欠息                0.018667
# 最近连续交易月数            0.013108
# 订单时间间隔均值（天）         0.011768
# 交易额均值               0.010849
# 交易额总量               0.010849
# 订单总数                0.008739

# %%
fa = pd.read_excel('./data/factorAnalysis.xlsx')
fa = fa.apply(abs)
factors =[]
for col in fa.columns:
    col = fa[col].sort_values(ascending=False)
    factors.append(col[col>0.2].index)
factors
# Out:
# [Index([u'交易量方差', u'交易额方差', u'交易额最大值', u'账期订单交易量均值', u'交易量最大值', u'账期订单交易额均值',
#         u'交易量均值', u'交易额均值', u'员工人数', u'厂房面积', u'交易总量', u'交易额总量', u'实收资本',
#         u'资产负债率', u'注册地址', u'货币资金', u'征信欠息', u'净资产增长率', u'涉诉信息', u'订单时间间隔均值（天）',
#         u'商标专利', u'征信关注', u'法人变更', u'注册时间', u'净资产', u'场地租赁', u'场地自有'],
#        dtype='object'),
#  Index([u'订单总数', u'供应商数量', u'最近连续交易月数', u'合作时间（月）', u'撮合单数', u'交易额最小值',
#         u'交易量最小值', u'账期合作时间（月）', u'交易总量', u'交易额总量', u'有无贷款', u'主营业务利润率',
#         u'货币资金', u'征信正常'],
#        dtype='object'),
#  Index([u'征信欠息', u'净资产', u'当地经济环境', u'交易额总量', u'注册时间', u'交易总量', u'涉诉信息',
#         u'征信正常', u'账期订单占比', u'交易额均值', u'交易量均值', u'合作时间（月）',
#         u'交易稳定性（近三个月交易量变化均值）', u'下游客户情况', u'订单时间间隔均值（天）', u'商标专利', u'账期订单交易额均值',
#         u'账期订单交易量均值', u'场地租赁', u'场地自有', u'资产负债率', u'订单总数', u'有无贷款', u'撮合单数'],
#        dtype='object'),
#  Index([u'商标专利', u'应收账款周转天数', u'注册地址', u'注册时间', u'订单时间间隔均值（天）', u'厂房面积',
#         u'员工人数', u'征信关注', u'主营业务利润率', u'合作时间（月）', u'销售增长率', u'净资产', u'有无贷款',
#         u'注册资本变更', u'实收资本', u'分支机构', u'存货周转天数', u'交易量最大值'],
#        dtype='object'),
#  Index([u'场地租赁', u'场地自有', u'征信正常', u'征信关注', u'下游客户情况', u'当地经济环境', u'货币资金',
#         u'有无贷款', u'注册地址', u'员工人数', u'厂房面积', u'涉诉信息', u'订单时间间隔均值（天）', u'供应商数量',
#         u'交易量最小值', u'交易额最小值', u'应收账款周转天数', u'净资产'],
#        dtype='object'),
#  Index([u'逾期占比', u'提前还款占比', u'有无贷款', u'撮合单数', u'账期合作时间（月）', u'账期订单占比', u'厂房面积',
#         u'员工人数', u'征信关注', u'订单时间间隔均值（天）', u'货币资金', u'征信正常', u'资产负债率'],
#        dtype='object'),
#  Index([u'流动比率', u'资产负债率', u'实收资本', u'下游客户情况', u'净资产', u'主营业务利润率', u'注册资本变更',
#         u'员工人数', u'货币资金'],
#        dtype='object'),
#  Index([u'最近交易（X月之前）', u'最近一笔账期订单（X月之前）', u'交易稳定性（近三个月交易量变化均值）', u'主营业务利润率'], dtype='object'),
#  Index([u'分支机构', u'涉诉信息', u'注册资本变更', u'厂房面积', u'货币资金', u'订单时间间隔均值（天）', u'实收资本',
#         u'下游客户情况'],
#        dtype='object'),
#  Index([u'销售增长率', u'交易额最小值', u'交易量最小值', u'注册资本变更', u'账期订单占比', u'流动比率', u'有无贷款',
#         u'注册时间', u'订单时间间隔均值（天）'],
#        dtype='object'),
#  Index([u'法人变更', u'账期订单占比', u'账期合作时间（月）', u'撮合单数', u'征信不良', u'净资产增长率',
#         u'下游客户情况', u'交易量最小值'],
#        dtype='object'),
#  Index([u'采购产品种类数量', u'净资产增长率', u'主营业务利润率', u'征信关注', u'下游客户情况', u'员工人数'], dtype='object'),
#  Index([u'存货周转天数', u'主营业务利润率', u'有无贷款', u'注册资本变更', u'实收资本', u'账期订单占比'], dtype='object')]

# %%
#IV
tmp = pd.DataFrame.from_dict([calc_iv(zq_all,box_num=3)]).T
tmp.sort_values(by=0,ascending=False)

zq_all = zq_7.append(zq_15)
zq_all =zq_all.append(zq_30)
zq_all

yq_corr =samples_all.corr()['yq_day'].sort_values(ascending=False)
label_corr =zq_all.corr()['label'].sort_values(ascending=False)

t = tmp.merge(yq_corr.reset_index(),left_index=True,right_on='yq_day',how='left')
t = t.merge(label_corr.reset_index(),left_index=True,right_on='label',how='left')
t
# Out:
#            0 index_x              yq_day index_y  label
# 54  0.323262     NaN              下游客户情况     NaN     55
# 54  0.086892     NaN             主营业务利润率     NaN     55
# 54  0.049739     NaN                交易总量     NaN     55
# 54  0.054690     NaN  交易稳定性（近三个月交易量变化均值）     NaN     55
# 54  0.117445     NaN               交易量均值     NaN     55
# 54  0.134158     NaN               交易量方差     NaN     55
# 54  0.045477     NaN              交易量最大值     NaN     55
# 54  0.123854     NaN              交易量最小值     NaN     55
# 54  0.094874     NaN               交易额均值     NaN     55
# 54  0.061288     NaN               交易额总量     NaN     55
# 54  0.077914     NaN               交易额方差     NaN     55
# 54  0.072502     NaN              交易额最大值     NaN     55
# 54  0.117344     NaN              交易额最小值     NaN     55
# 54  0.100183     NaN               供应商数量     NaN     55
# 54  0.096791     NaN                 净资产     NaN     55
# 54  0.036988     NaN              净资产增长率     NaN     55
# 54  0.001803     NaN                分支机构     NaN     55
# 54  0.187960     NaN                厂房面积     NaN     55
# 54  0.053042     NaN             合作时间（月）     NaN     55
# 54  0.204950     NaN                员工人数     NaN     55
# 54  0.092123     NaN                商标专利     NaN     55
# 54  0.118460     NaN                场地租赁     NaN     55
# 54  0.118460     NaN                场地自有     NaN     55
# 54  0.280086     NaN              存货周转天数     NaN     55
# 54  0.250464     NaN                实收资本     NaN     55
# 54  0.073002     NaN            应收账款周转天数     NaN     55
# 54  0.063321     NaN              当地经济环境     NaN     55
# 54  0.044167     NaN                征信不良     NaN     55
# 54  0.176426     NaN                征信关注     NaN     55
# 54  0.032531     NaN                征信欠息     NaN     55
# 54  0.031237     NaN                征信正常     NaN     55
# 54  0.520354     NaN              提前还款占比     NaN     55
# 54  0.037414     NaN                撮合单数     NaN     55
# 54  0.014088     NaN      最近一笔账期订单（X月之前）     NaN     55
# 54  0.016517     NaN          最近交易（X月之前）     NaN     55
# 54  0.022470     NaN            最近连续交易月数     NaN     55
# 54  0.039329     NaN                有无贷款     NaN     55
# 54  0.001012     NaN                法人变更     NaN     55
# 54  0.091191     NaN                注册地址     NaN     55
# 54  0.101644     NaN                注册时间     NaN     55
# 54  0.012971     NaN              注册资本变更     NaN     55
# 54  0.306512     NaN                流动比率     NaN     55
# 54  0.068035     NaN                涉诉信息     NaN     55
# 54  0.020137     NaN                订单总数     NaN     55
# 54  0.071379     NaN         订单时间间隔均值（天）     NaN     55
# 54  0.038996     NaN           账期合作时间（月）     NaN     55
# 54  0.151385     NaN           账期订单交易量均值     NaN     55
# 54  0.084485     NaN           账期订单交易额均值     NaN     55
# 54  0.058643     NaN              账期订单占比     NaN     55
# 54  0.104203     NaN                货币资金     NaN     55
# 54  0.282758     NaN               资产负债率     NaN     55
# 54  0.411139     NaN                逾期占比     NaN     55
# 54  0.016289     NaN            采购产品种类数量     NaN     55
# 54  0.014188     NaN               销售增长率     NaN     55

# %%
# tmp.columns =['index','ivs']
tmp.index
# Out:
# Index([u'下游客户情况', u'主营业务利润率', u'交易总量', u'交易稳定性（近三个月交易量变化均值）', u'交易量均值',
#        u'交易量方差', u'交易量最大值', u'交易量最小值', u'交易额均值', u'交易额总量', u'交易额方差', u'交易额最大值',
#        u'交易额最小值', u'供应商数量', u'净资产', u'净资产增长率', u'分支机构', u'厂房面积', u'合作时间（月）',
#        u'员工人数', u'商标专利', u'场地租赁', u'场地自有', u'存货周转天数', u'实收资本', u'应收账款周转天数',
#        u'当地经济环境', u'征信不良', u'征信关注', u'征信欠息', u'征信正常', u'提前还款占比', u'撮合单数',
#        u'最近一笔账期订单（X月之前）', u'最近交易（X月之前）', u'最近连续交易月数', u'有无贷款', u'法人变更',
#        u'注册地址', u'注册时间', u'注册资本变更', u'流动比率', u'涉诉信息', u'订单总数', u'订单时间间隔均值（天）',
#        u'账期合作时间（月）', u'账期订单交易量均值', u'账期订单交易额均值', u'账期订单占比', u'货币资金', u'资产负债率',
#        u'逾期占比', u'采购产品种类数量', u'销售增长率'],
#       dtype='object')

# %%
#重复订单
tmp = samples_all.groupby(by=[u'应收单号']).count()['订单总数']
l = tmp[tmp>1].index
loan_all[loan_all[u'应收单号'].isin(l)].to_csv('./data/tmp.csv')
